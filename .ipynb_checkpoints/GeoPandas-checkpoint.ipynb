# %% [markdown]
# # Introduction to GeoPandas 🐼
#
#
# [GeoPandas](https://geopandas.org/en/stable/index.html) The goal of GeoPandas is to make working with geospatial data in python easier. It combines the capabilities of pandas and shapely, providing geospatial operations in pandas and a high-level interface to multiple geometries to shapely. GeoPandas enables you to easily do operations in python that would otherwise require a spatial database such as PostGIS.

# %% [markdown]
# ## Getting Started with GeoPandas
#
# <img src="geopanda.png" alt="geopandas" width="400"/>
#
# Let's first install GeoPandas on Taylor.
#
# -Select Terminal from Launcher
#
# -Once in terminal input the following commands:
#
# `git clone https://github.com/geopandas/geopandas.git`
#
# `cd geopandas`
#
# `pip install .`
#
# -Open up Jupyter Notebook
#
# -Add code chunk
#
# -Import geopandas
#
# ```python
# import geopandas
# ```
#
# We will also be using functions from matplotlib.pyplot.
#
# -Import pyplot
#
# ```python
# import matplotlib.pyplot as plt
# ```
#
#
# <div class="run">
#     ▶️ <b> Run the cell below. </b>
# </div>

# %%
import geopandas
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exploring data
# <hr style="border-top: 0.2px solid gray; margin-top: 12px; margin-bottom: 1px"></hr>
#
# There are three built in datasets in the GeoPandas package:
#
# -naturalearth_cities
#
# -naturalearth_lowres
#
# -nybb
#
# To see what data is available use the following method below:
# ```python
# geopandas.datasets.available
# ```
#
# <div class="run">
#     ▶️ <b> Run the cell below. </b>
# </div>

# %%
# Returns names of available maps
geopandas.datasets.available
# Out:
# ['naturalearth_lowres', 'naturalearth_cities', 'nybb']

# %% [markdown]
# ### Reading in the data
# <hr style="border-top: 0.2px solid gray; margin-top: 12px; margin-bottom: 1px"></hr>
# We want to use the naturalearth_lowres dataset
#
# To read in the data we will need to use the method below:
# ```python
# geopandas.datasets.get_path('naturalearth_lowres')
# ```
#
# <div class="run">
#     ▶️ <b> Run the cell below. </b>
# </div>

# %%
# Returns path of a particular map
geopandas.datasets.get_path('naturalearth_lowres')
# Out:
# '/Users/rbe786/.local/lib/python3.10/site-packages/geopandas/datasets/naturalearth_lowres/naturalearth_lowres.shp'

# %%
#Exploring the dataset

print(world.info())

world
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   pop_est     177 non-null    float64
#  1   continent   177 non-null    object
#  2   name        177 non-null    object
#  3   iso_a3      177 non-null    object
#  4   gdp_md_est  177 non-null    int64
#  5   geometry    177 non-null    geometry
# dtypes: float64(1), geometry(1), int64(1), object(3)
# memory usage: 8.4+ KB
# None
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# ...

# %% [markdown]
# ### Exploring Map Plots
# <hr style="border-top: 0.2px solid gray; margin-top: 12px; margin-bottom: 1px"></hr>
# With GeoPandas you can see a map of the whole world, or if you'd like just a specific part of the world.
#
#
# <div class="run">
#     ▶️ <b> Run the cell below. </b>
# </div>

# %%
# Opens the map as a GeoDataFrame
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# Subsets the GeoDataFrame
usa = world[world.name == "United States of America"]

# Plots
world.plot();
usa.plot()
# Out:
# <AxesSubplot:>

# %%
#creating Africa subset
africa = world[world.continent == 'Africa']

#creating a new population column with population in millions
africa['pop_millions'] = africa['pop_est'] / 1000000

#checking to make sure that everything worked out :) 
africa.head()
# Out:
# /Users/rbe786/.local/lib/python3.10/site-packages/geopandas/geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#        pop_est continent             name iso_a3  gdp_md_est  \
# 1   58005463.0    Africa         Tanzania    TZA       63177
# 2     603253.0    Africa        W. Sahara    ESH         907
# 11  86790567.0    Africa  Dem. Rep. Congo    COD       50400
# 12  10192317.3    Africa          Somalia    SOM        4719
# 13  52573973.0    Africa            Kenya    KEN       95503
#
#                                              geometry  pop_millions
# 1   POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...     58.005463
# ...

# %%
#creating the plot
africa.plot(column = 'pop_millions', #column corresponds to the color
            legend = True, 
            legend_kwds = {'label': "Population by Country (in millions)",
                          'orientation': "horizontal"}) #customizing the legend

plt.title("Population of Countries in Africa") #adding a title
plt.ylabel("Longitude") #adding y axis label
plt.xlabel("Latitude") #adding x axis label
# Out:
# Text(0.5, 134.40222222222226, 'Latitude')

# %%
import geoviews as gv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import geoviews as gv
#
# ModuleNotFoundError: No module named 'geoviews'
